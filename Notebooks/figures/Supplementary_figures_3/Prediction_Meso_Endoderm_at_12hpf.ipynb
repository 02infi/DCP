# %%
import deep_predictor
from collections.abc import Mapping
import torch
import scanpy as sc
# Out:
# Global seed set to 0
# /home/gaurav/anaconda3/envs/project/lib/python3.10/site-packages/pytorch_lightning/utilities/warnings.py:53: LightningDeprecationWarning: pytorch_lightning.utilities.warnings.rank_zero_deprecation has been deprecated in v1.6 and will be removed in v1.8. Use the equivalent function from the pytorch_lightning.utilities.rank_zero module instead.
#   new_rank_zero_deprecation(
# /home/gaurav/anaconda3/envs/project/lib/python3.10/site-packages/pytorch_lightning/utilities/warnings.py:58: LightningDeprecationWarning: The `pytorch_lightning.loggers.base.rank_zero_experiment` is deprecated in v1.7 and will be removed in v1.9. Please use `pytorch_lightning.loggers.logger.rank_zero_experiment` instead.
#   return new_rank_zero_deprecation(*args, **kwargs)

# %%
import scipy.stats as ss
import numpy as np
import scipy.stats as ss
sc.set_figure_params(dpi=250, color_map='viridis')  # low dpi (dots per inch) yields small inline figures
import pandas as pd

# %%
import numpy as np
import pandas as pd

# %%
adata = sc.read("/home/gaurav/Gaurav/Berlin/Deep_Learning/Experiment/PCA_UMAP/VAE_models/VAE_models/normalised_model/farrel_normalised.h5ad")

# %%
#Training Data
segments = [8,61,19,64,2,59,50,70,56,16,69,60,1,10,55,57,53]
training_data = adata[adata.obs['segment'] == 72]
training_data = training_data[training_data.obs['HPF'] == 5.3]
for segment in segments:
    segment_data = adata[adata.obs['segment'] == segment]
    segment_data = segment_data[segment_data.obs['HPF'] == 12]
    training_data = training_data.concatenate(segment_data)
training_data.obs["cells"] = "Training data"
# Out:
# /home/gaurav/anaconda3/envs/project/lib/python3.10/site-packages/anndata/_core/anndata.py:1785: FutureWarning: X.dtype being converted to np.float32 from float64. In the next version of anndata (0.9) conversion will not be automatic. Pass dtype explicitly to avoid this warning. Pass `AnnData(X, dtype=X.dtype, ...)` to get the future behavour.
#   [AnnData(sparse.csr_matrix(a.shape), obs=a.obs) for a in all_adatas],
# /home/gaurav/anaconda3/envs/project/lib/python3.10/site-packages/anndata/_core/anndata.py:1785: FutureWarning: X.dtype being converted to np.float32 from float64. In the next version of anndata (0.9) conversion will not be automatic. Pass dtype explicitly to avoid this warning. Pass `AnnData(X, dtype=X.dtype, ...)` to get the future behavour.
#   [AnnData(sparse.csr_matrix(a.shape), obs=a.obs) for a in all_adatas],
# /home/gaurav/anaconda3/envs/project/lib/python3.10/site-packages/anndata/_core/anndata.py:1785: FutureWarning: X.dtype being converted to np.float32 from float64. In the next version of anndata (0.9) conversion will not be automatic. Pass dtype explicitly to avoid this warning. Pass `AnnData(X, dtype=X.dtype, ...)` to get the future behavour.
#   [AnnData(sparse.csr_matrix(a.shape), obs=a.obs) for a in all_adatas],
# /home/gaurav/anaconda3/envs/project/lib/python3.10/site-packages/anndata/_core/anndata.py:1785: FutureWarning: X.dtype being converted to np.float32 from float64. In the next version of anndata (0.9) conversion will not be automatic. Pass dtype explicitly to avoid this warning. Pass `AnnData(X, dtype=X.dtype, ...)` to get the future behavour.
#   [AnnData(sparse.csr_matrix(a.shape), obs=a.obs) for a in all_adatas],
# /home/gaurav/anaconda3/envs/project/lib/python3.10/site-packages/anndata/_core/anndata.py:1785: FutureWarning: X.dtype being converted to np.float32 from float64. In the next version of anndata (0.9) conversion will not be automatic. Pass dtype explicitly to avoid this warning. Pass `AnnData(X, dtype=X.dtype, ...)` to get the future behavour.
#   [AnnData(sparse.csr_matrix(a.shape), obs=a.obs) for a in all_adatas],
# /home/gaurav/anaconda3/envs/project/lib/python3.10/site-packages/anndata/_core/anndata.py:1785: FutureWarning: X.dtype being converted to np.float32 from float64. In the next version of anndata (0.9) conversion will not be automatic. Pass dtype explicitly to avoid this warning. Pass `AnnData(X, dtype=X.dtype, ...)` to get the future behavour.
#   [AnnData(sparse.csr_matrix(a.shape), obs=a.obs) for a in all_adatas],
# /home/gaurav/anaconda3/envs/project/lib/python3.10/site-packages/anndata/_core/anndata.py:1785: FutureWarning: X.dtype being converted to np.float32 from float64. In the next version of anndata (0.9) conversion will not be automatic. Pass dtype explicitly to avoid this warning. Pass `AnnData(X, dtype=X.dtype, ...)` to get the future behavour.
#   [AnnData(sparse.csr_matrix(a.shape), obs=a.obs) for a in all_adatas],
# /home/gaurav/anaconda3/envs/project/lib/python3.10/site-packages/anndata/_core/anndata.py:1785: FutureWarning: X.dtype being converted to np.float32 from float64. In the next version of anndata (0.9) conversion will not be automatic. Pass dtype explicitly to avoid this warning. Pass `AnnData(X, dtype=X.dtype, ...)` to get the future behavour.
#   [AnnData(sparse.csr_matrix(a.shape), obs=a.obs) for a in all_adatas],
# /home/gaurav/anaconda3/envs/project/lib/python3.10/site-packages/anndata/_core/anndata.py:1785: FutureWarning: X.dtype being converted to np.float32 from float64. In the next version of anndata (0.9) conversion will not be automatic. Pass dtype explicitly to avoid this warning. Pass `AnnData(X, dtype=X.dtype, ...)` to get the future behavour.
#   [AnnData(sparse.csr_matrix(a.shape), obs=a.obs) for a in all_adatas],
# /home/gaurav/anaconda3/envs/project/lib/python3.10/site-packages/anndata/_core/anndata.py:1785: FutureWarning: X.dtype being converted to np.float32 from float64. In the next version of anndata (0.9) conversion will not be automatic. Pass dtype explicitly to avoid this warning. Pass `AnnData(X, dtype=X.dtype, ...)` to get the future behavour.
#   [AnnData(sparse.csr_matrix(a.shape), obs=a.obs) for a in all_adatas],
# /home/gaurav/anaconda3/envs/project/lib/python3.10/site-packages/anndata/_core/anndata.py:1785: FutureWarning: X.dtype being converted to np.float32 from float64. In the next version of anndata (0.9) conversion will not be automatic. Pass dtype explicitly to avoid this warning. Pass `AnnData(X, dtype=X.dtype, ...)` to get the future behavour.
#   [AnnData(sparse.csr_matrix(a.shape), obs=a.obs) for a in all_adatas],
# /home/gaurav/anaconda3/envs/project/lib/python3.10/site-packages/anndata/_core/anndata.py:1785: FutureWarning: X.dtype being converted to np.float32 from float64. In the next version of anndata (0.9) conversion will not be automatic. Pass dtype explicitly to avoid this warning. Pass `AnnData(X, dtype=X.dtype, ...)` to get the future behavour.
#   [AnnData(sparse.csr_matrix(a.shape), obs=a.obs) for a in all_adatas],
# /home/gaurav/anaconda3/envs/project/lib/python3.10/site-packages/anndata/_core/anndata.py:1785: FutureWarning: X.dtype being converted to np.float32 from float64. In the next version of anndata (0.9) conversion will not be automatic. Pass dtype explicitly to avoid this warning. Pass `AnnData(X, dtype=X.dtype, ...)` to get the future behavour.
#   [AnnData(sparse.csr_matrix(a.shape), obs=a.obs) for a in all_adatas],
# /home/gaurav/anaconda3/envs/project/lib/python3.10/site-packages/anndata/_core/anndata.py:1785: FutureWarning: X.dtype being converted to np.float32 from float64. In the next version of anndata (0.9) conversion will not be automatic. Pass dtype explicitly to avoid this warning. Pass `AnnData(X, dtype=X.dtype, ...)` to get the future behavour.
#   [AnnData(sparse.csr_matrix(a.shape), obs=a.obs) for a in all_adatas],
# /home/gaurav/anaconda3/envs/project/lib/python3.10/site-packages/anndata/_core/anndata.py:1785: FutureWarning: X.dtype being converted to np.float32 from float64. In the next version of anndata (0.9) conversion will not be automatic. Pass dtype explicitly to avoid this warning. Pass `AnnData(X, dtype=X.dtype, ...)` to get the future behavour.
#   [AnnData(sparse.csr_matrix(a.shape), obs=a.obs) for a in all_adatas],
# /home/gaurav/anaconda3/envs/project/lib/python3.10/site-packages/anndata/_core/anndata.py:1785: FutureWarning: X.dtype being converted to np.float32 from float64. In the next version of anndata (0.9) conversion will not be automatic. Pass dtype explicitly to avoid this warning. Pass `AnnData(X, dtype=X.dtype, ...)` to get the future behavour.
#   [AnnData(sparse.csr_matrix(a.shape), obs=a.obs) for a in all_adatas],
# /home/gaurav/anaconda3/envs/project/lib/python3.10/site-packages/anndata/_core/anndata.py:1785: FutureWarning: X.dtype being converted to np.float32 from float64. In the next version of anndata (0.9) conversion will not be automatic. Pass dtype explicitly to avoid this warning. Pass `AnnData(X, dtype=X.dtype, ...)` to get the future behavour.
#   [AnnData(sparse.csr_matrix(a.shape), obs=a.obs) for a in all_adatas],

# %%
#Lambda = np.shape(training_data.X)[1]
#zebra_obj = deep_predictor.DeepPredictor(training_data,latent_dim=100,hidden_layers=[800,800],workers=8,parameters=[0,0,0,Lambda,1],likelihood="nb",batch_size=100)
zebra_obj = deep_predictor.DeepPredictor(training_data,latent_dim=100,hidden_layers=[800,800],workers=8,parameters=[0,0,0,1,1],likelihood="nb",batch_size=100)
# Out:
# /home/gaurav/anaconda3/envs/project/lib/python3.10/site-packages/torch/cuda/__init__.py:82: UserWarning: CUDA initialization: The NVIDIA driver on your system is too old (found version 10010). Please update your GPU driver by downloading and installing a new version from the URL: http://www.nvidia.com/Download/index.aspx Alternatively, go to: https://pytorch.org to install a PyTorch version that has been compiled with your version of the CUDA driver. (Triggered internally at  /opt/conda/conda-bld/pytorch_1646755853668/work/c10/cuda/CUDAFunctions.cpp:112.)
#   return torch._C._cuda_getDeviceCount() > 0

# %%
#zebra_obj.reload_model(path="/home/gaurav/Gaurav/Berlin/Deep_Learning/Project/models/NB_KL/withouttestdata/zebra_ecto_trained_00011_highDimby_without_testdata/model_lambda_batch_100_KL.pt") # NB + KL
zebra_obj.reload_model(path="/home/gaurav/Gaurav/Berlin/Deep_Learning/Project/models/NB_MMD/withouttestdata/zebra_ecto_trained_00011_highDimby_without_testdata/model.pt") # NB + MMD

# %%
adata_test = 0
Segments = [71,3,34,12,75,62,52,58,73,17,26,76,5,18]
Real_data = adata[adata.obs['segment'] == 74]
Real_data = Real_data[Real_data.obs['HPF'] == 12]
Real_data.obs["cells"] = "Real data"
seg_data = 0
for segment in Segments:
    seg_data = adata[adata.obs['segment'] == segment]
    seg_data = seg_data[seg_data.obs['HPF'] == 12]
    seg_data.obs["cells"] = "Real data"
    Real_data = Real_data.concatenate(seg_data)


temp_data = adata[adata.obs['segment'] == 78]
Test_data = temp_data[temp_data.obs['HPF'] == 5.3]
Test_data.obs["cells"] = "Test data"

adata_test = Real_data.concatenate(Test_data)
# Out:
# /tmp/ipykernel_6430/990710221.py:5: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   Real_data.obs["cells"] = "Real data"
# /tmp/ipykernel_6430/990710221.py:10: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   seg_data.obs["cells"] = "Real data"
# /home/gaurav/anaconda3/envs/project/lib/python3.10/site-packages/anndata/_core/anndata.py:1785: FutureWarning: X.dtype being converted to np.float32 from float64. In the next version of anndata (0.9) conversion will not be automatic. Pass dtype explicitly to avoid this warning. Pass `AnnData(X, dtype=X.dtype, ...)` to get the future behavour.
#   [AnnData(sparse.csr_matrix(a.shape), obs=a.obs) for a in all_adatas],
# /tmp/ipykernel_6430/990710221.py:10: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   seg_data.obs["cells"] = "Real data"
# /home/gaurav/anaconda3/envs/project/lib/python3.10/site-packages/anndata/_core/anndata.py:1785: FutureWarning: X.dtype being converted to np.float32 from float64. In the next version of anndata (0.9) conversion will not be automatic. Pass dtype explicitly to avoid this warning. Pass `AnnData(X, dtype=X.dtype, ...)` to get the future behavour.
#   [AnnData(sparse.csr_matrix(a.shape), obs=a.obs) for a in all_adatas],
# /tmp/ipykernel_6430/990710221.py:10: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   seg_data.obs["cells"] = "Real data"
# /home/gaurav/anaconda3/envs/project/lib/python3.10/site-packages/anndata/_core/anndata.py:1785: FutureWarning: X.dtype being converted to np.float32 from float64. In the next version of anndata (0.9) conversion will not be automatic. Pass dtype explicitly to avoid this warning. Pass `AnnData(X, dtype=X.dtype, ...)` to get the future behavour.
#   [AnnData(sparse.csr_matrix(a.shape), obs=a.obs) for a in all_adatas],
# /tmp/ipykernel_6430/990710221.py:10: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   seg_data.obs["cells"] = "Real data"
# /home/gaurav/anaconda3/envs/project/lib/python3.10/site-packages/anndata/_core/anndata.py:1785: FutureWarning: X.dtype being converted to np.float32 from float64. In the next version of anndata (0.9) conversion will not be automatic. Pass dtype explicitly to avoid this warning. Pass `AnnData(X, dtype=X.dtype, ...)` to get the future behavour.
#   [AnnData(sparse.csr_matrix(a.shape), obs=a.obs) for a in all_adatas],
# /tmp/ipykernel_6430/990710221.py:10: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   seg_data.obs["cells"] = "Real data"
# /home/gaurav/anaconda3/envs/project/lib/python3.10/site-packages/anndata/_core/anndata.py:1785: FutureWarning: X.dtype being converted to np.float32 from float64. In the next version of anndata (0.9) conversion will not be automatic. Pass dtype explicitly to avoid this warning. Pass `AnnData(X, dtype=X.dtype, ...)` to get the future behavour.
#   [AnnData(sparse.csr_matrix(a.shape), obs=a.obs) for a in all_adatas],
# /tmp/ipykernel_6430/990710221.py:10: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   seg_data.obs["cells"] = "Real data"
# /home/gaurav/anaconda3/envs/project/lib/python3.10/site-packages/anndata/_core/anndata.py:1785: FutureWarning: X.dtype being converted to np.float32 from float64. In the next version of anndata (0.9) conversion will not be automatic. Pass dtype explicitly to avoid this warning. Pass `AnnData(X, dtype=X.dtype, ...)` to get the future behavour.
#   [AnnData(sparse.csr_matrix(a.shape), obs=a.obs) for a in all_adatas],
# /tmp/ipykernel_6430/990710221.py:10: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   seg_data.obs["cells"] = "Real data"
# /home/gaurav/anaconda3/envs/project/lib/python3.10/site-packages/anndata/_core/anndata.py:1785: FutureWarning: X.dtype being converted to np.float32 from float64. In the next version of anndata (0.9) conversion will not be automatic. Pass dtype explicitly to avoid this warning. Pass `AnnData(X, dtype=X.dtype, ...)` to get the future behavour.
#   [AnnData(sparse.csr_matrix(a.shape), obs=a.obs) for a in all_adatas],
# /tmp/ipykernel_6430/990710221.py:10: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   seg_data.obs["cells"] = "Real data"
# /home/gaurav/anaconda3/envs/project/lib/python3.10/site-packages/anndata/_core/anndata.py:1785: FutureWarning: X.dtype being converted to np.float32 from float64. In the next version of anndata (0.9) conversion will not be automatic. Pass dtype explicitly to avoid this warning. Pass `AnnData(X, dtype=X.dtype, ...)` to get the future behavour.
#   [AnnData(sparse.csr_matrix(a.shape), obs=a.obs) for a in all_adatas],
# /tmp/ipykernel_6430/990710221.py:10: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   seg_data.obs["cells"] = "Real data"
# /home/gaurav/anaconda3/envs/project/lib/python3.10/site-packages/anndata/_core/anndata.py:1785: FutureWarning: X.dtype being converted to np.float32 from float64. In the next version of anndata (0.9) conversion will not be automatic. Pass dtype explicitly to avoid this warning. Pass `AnnData(X, dtype=X.dtype, ...)` to get the future behavour.
#   [AnnData(sparse.csr_matrix(a.shape), obs=a.obs) for a in all_adatas],
# /tmp/ipykernel_6430/990710221.py:10: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   seg_data.obs["cells"] = "Real data"
# /home/gaurav/anaconda3/envs/project/lib/python3.10/site-packages/anndata/_core/anndata.py:1785: FutureWarning: X.dtype being converted to np.float32 from float64. In the next version of anndata (0.9) conversion will not be automatic. Pass dtype explicitly to avoid this warning. Pass `AnnData(X, dtype=X.dtype, ...)` to get the future behavour.
#   [AnnData(sparse.csr_matrix(a.shape), obs=a.obs) for a in all_adatas],
# /tmp/ipykernel_6430/990710221.py:10: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   seg_data.obs["cells"] = "Real data"
# /home/gaurav/anaconda3/envs/project/lib/python3.10/site-packages/anndata/_core/anndata.py:1785: FutureWarning: X.dtype being converted to np.float32 from float64. In the next version of anndata (0.9) conversion will not be automatic. Pass dtype explicitly to avoid this warning. Pass `AnnData(X, dtype=X.dtype, ...)` to get the future behavour.
#   [AnnData(sparse.csr_matrix(a.shape), obs=a.obs) for a in all_adatas],
# /tmp/ipykernel_6430/990710221.py:10: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   seg_data.obs["cells"] = "Real data"
# /home/gaurav/anaconda3/envs/project/lib/python3.10/site-packages/anndata/_core/anndata.py:1785: FutureWarning: X.dtype being converted to np.float32 from float64. In the next version of anndata (0.9) conversion will not be automatic. Pass dtype explicitly to avoid this warning. Pass `AnnData(X, dtype=X.dtype, ...)` to get the future behavour.
#   [AnnData(sparse.csr_matrix(a.shape), obs=a.obs) for a in all_adatas],
# /tmp/ipykernel_6430/990710221.py:10: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   seg_data.obs["cells"] = "Real data"
# /home/gaurav/anaconda3/envs/project/lib/python3.10/site-packages/anndata/_core/anndata.py:1785: FutureWarning: X.dtype being converted to np.float32 from float64. In the next version of anndata (0.9) conversion will not be automatic. Pass dtype explicitly to avoid this warning. Pass `AnnData(X, dtype=X.dtype, ...)` to get the future behavour.
#   [AnnData(sparse.csr_matrix(a.shape), obs=a.obs) for a in all_adatas],
# /tmp/ipykernel_6430/990710221.py:10: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   seg_data.obs["cells"] = "Real data"
# /home/gaurav/anaconda3/envs/project/lib/python3.10/site-packages/anndata/_core/anndata.py:1785: FutureWarning: X.dtype being converted to np.float32 from float64. In the next version of anndata (0.9) conversion will not be automatic. Pass dtype explicitly to avoid this warning. Pass `AnnData(X, dtype=X.dtype, ...)` to get the future behavour.
#   [AnnData(sparse.csr_matrix(a.shape), obs=a.obs) for a in all_adatas],
# /tmp/ipykernel_6430/990710221.py:16: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   Test_data.obs["cells"] = "Test data"
# /home/gaurav/anaconda3/envs/project/lib/python3.10/site-packages/anndata/_core/anndata.py:1785: FutureWarning: X.dtype being converted to np.float32 from float64. In the next version of anndata (0.9) conversion will not be automatic. Pass dtype explicitly to avoid this warning. Pass `AnnData(X, dtype=X.dtype, ...)` to get the future behavour.
#   [AnnData(sparse.csr_matrix(a.shape), obs=a.obs) for a in all_adatas],

# %%
zebra_obj.runFlows(5.3,12,"HPF",adata_test)

# %%
zebra_obj.trainFlows(iterations=100)
# Out:
# Loss (it. 0) : -31.306779
# Loss (it. 50) : -32.812238

# %%
adata_meso_endo_forward,px_scale,theta,px_rate = zebra_obj.predict(adata_test,5.3,12,"HPF")
# Out:
# /home/gaurav/anaconda3/envs/project/lib/python3.10/site-packages/anndata/_core/anndata.py:1785: FutureWarning: X.dtype being converted to np.float32 from float64. In the next version of anndata (0.9) conversion will not be automatic. Pass dtype explicitly to avoid this warning. Pass `AnnData(X, dtype=X.dtype, ...)` to get the future behavour.
#   [AnnData(sparse.csr_matrix(a.shape), obs=a.obs) for a in all_adatas],

# %%
#adata_meso_endo_forward.X = expTransform(adata_meso_endo_forward.X)

# %%
pca_pal = ["#d62728","#ff7f0e","#1f77b4"]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats



def corrfunc(x, y, **kws):
	slope, intercept, r, p_value, _err = stats.linregress(x, y)
	ax = plt.gca()
	ax.annotate("$R^2$ = {:.2f}".format(r**2),
				xy=(.1, .9), xycoords=ax.transAxes)


def Plotting_Correlation_genes(data_object,title,scatter_color):
    real_data = data_object[data_object.obs["cells"] == "Real data",:]
    pred_data =  data_object[data_object.obs["cells"] == "Predicted data",:] 
    scanpy_obj_data = np.vstack((np.average(real_data.X,axis = 0),np.average(pred_data.X,axis = 0)))
    X = "Real data"
    Y = "Predicted data"
    scanpy_obj_data_df = pd.DataFrame(scanpy_obj_data.T,columns=[X,Y])
    corrfunc(scanpy_obj_data[0],scanpy_obj_data[1])
    ax = sns.regplot(data = scanpy_obj_data_df,x = X ,y = Y,scatter=True,scatter_kws={'s':10},marker = "o",color=scatter_color)
    major_ticks = np.arange(0, 100,20)
    ax.set_xticks(major_ticks)
    ax.set_yticks(major_ticks)
    #plt.xlim(0,80) 
    #plt.ylim(0,80)
    plt.grid(False)
    sns.despine(offset=5)
    plt.xlabel(X,fontsize = 20)
    plt.ylabel(Y,fontsize = 20)    
    plt.tick_params(labelsize=20)
    plt.title(title,fontsize = 20)   
    plt.show()
    
def Plotting_Correlation_var(data_object,title,scatter_color):
    real_data = data_object[data_object.obs["cells"] == "Real data",:]
    pred_data =  data_object[data_object.obs["cells"] == "Predicted data",:] 
    scanpy_obj_data = np.vstack((np.std(real_data.X,axis = 0),np.std(pred_data.X,axis = 0)))
    X = "Real data"
    Y = "Predicted data"
    scanpy_obj_data_df = pd.DataFrame(scanpy_obj_data.T,columns=[X,Y])
    corrfunc(scanpy_obj_data[0],scanpy_obj_data[1])
    ax = sns.regplot(data = scanpy_obj_data_df,x = X ,y = Y,scatter=True,scatter_kws={'s':10},marker = "o",color=scatter_color)
    major_ticks = np.arange(0, 25,10)
    ax.set_xticks(major_ticks)
    ax.set_yticks(major_ticks)
    sns.despine(offset=2)
    plt.xlim(-1,30) 
    plt.ylim(-1,30)
    plt.grid(False)
    plt.xlabel(X,fontsize = 20)
    plt.ylabel(Y,fontsize = 20)    
    plt.tick_params(labelsize=20)
    plt.title(title,fontsize = 20)
    plt.show()

# %%
Plotting_Correlation_genes(adata_meso_endo_forward," ",pca_pal[2])

# %%
Plotting_Correlation_var(adata_meso_endo_forward," ",pca_pal[2])

# %%
def Calculating_PCA(data_object):
	sc.tl.pca(data_object)
    
pca_pal_ = ["#1f77b4","grey","darkgrey"]

# %%
Calculating_PCA(adata_meso_endo_forward)

# %%
sc.pl.pca(adata_meso_endo_forward, color="cells",size=50,alpha = 0.5,palette=pca_pal_)

# %%
adata_ = zebra_obj.Transition_state()
# Out:
# /home/gaurav/anaconda3/envs/project/lib/python3.10/site-packages/anndata/_core/anndata.py:1785: FutureWarning: X.dtype being converted to np.float32 from float64. In the next version of anndata (0.9) conversion will not be automatic. Pass dtype explicitly to avoid this warning. Pass `AnnData(X, dtype=X.dtype, ...)` to get the future behavour.
#   [AnnData(sparse.csr_matrix(a.shape), obs=a.obs) for a in all_adatas],

# %%
adata_wtl = adata_[adata_.obs["cells"] != "Predicted data Linear"]
adata_wtl = adata_wtl[adata_wtl.obs["cells"] != "Predicted data"]
pred_data = adata_[adata_.obs["cells"] =="Predicted data"]
pred_data_linear = adata_[adata_.obs["cells"] =="Predicted data Linear"]
adata_ = pred_data.concatenate(adata_wtl,pred_data_linear)
# Out:
# /home/gaurav/anaconda3/envs/project/lib/python3.10/site-packages/anndata/_core/anndata.py:1785: FutureWarning: X.dtype being converted to np.float32 from float64. In the next version of anndata (0.9) conversion will not be automatic. Pass dtype explicitly to avoid this warning. Pass `AnnData(X, dtype=X.dtype, ...)` to get the future behavour.
#   [AnnData(sparse.csr_matrix(a.shape), obs=a.obs) for a in all_adatas],

# %%
sc.tl.pca(adata_)

# %%
sc.pl.pca(adata_, color="cells",size=50,alpha = 0.6,palette=["#FFFFFF00","#1f77b4","grey","darkgrey"])

# %%
adata_trans = adata_[adata_.obs["cells"] != "Predicted data Linear"]
adata_trans = adata_trans[adata_trans.obs["cells"] != "Predicted data"]
adata_trans = adata_trans.concatenate(adata_[adata_.obs["cells"] == "Predicted data"])
sc.pl.pca(adata_trans, color="cells",size=50,alpha = 0.6,palette=["#1f77b4","grey","darkgrey"])
# Out:
# /home/gaurav/anaconda3/envs/project/lib/python3.10/site-packages/anndata/_core/anndata.py:1785: FutureWarning: X.dtype being converted to np.float32 from float64. In the next version of anndata (0.9) conversion will not be automatic. Pass dtype explicitly to avoid this warning. Pass `AnnData(X, dtype=X.dtype, ...)` to get the future behavour.
#   [AnnData(sparse.csr_matrix(a.shape), obs=a.obs) for a in all_adatas],

# %%
adata_trans = adata_trans[adata_trans.obs["cells"] != "Predicted data"]
sc.pl.pca(adata_trans, color="cells",size=50,alpha = 0.6,palette=["grey","darkgrey"])
# Out:
# /home/gaurav/anaconda3/envs/project/lib/python3.10/site-packages/anndata/compat/_overloaded_dict.py:106: ImplicitModificationWarning: Trying to modify attribute `._uns` of view, initializing view as actual.
#   self.data[key] = value

# %%
C_mean,C_var,M_mean,M_var = zebra_obj.Simulations(adata_test,5.3,12,"HPF",sim_num=25)
# Out:
# /home/gaurav/anaconda3/envs/project/lib/python3.10/site-packages/anndata/_core/anndata.py:1785: FutureWarning: X.dtype being converted to np.float32 from float64. In the next version of anndata (0.9) conversion will not be automatic. Pass dtype explicitly to avoid this warning. Pass `AnnData(X, dtype=X.dtype, ...)` to get the future behavour.
#   [AnnData(sparse.csr_matrix(a.shape), obs=a.obs) for a in all_adatas],
# /home/gaurav/anaconda3/envs/project/lib/python3.10/site-packages/anndata/_core/anndata.py:1785: FutureWarning: X.dtype being converted to np.float32 from float64. In the next version of anndata (0.9) conversion will not be automatic. Pass dtype explicitly to avoid this warning. Pass `AnnData(X, dtype=X.dtype, ...)` to get the future behavour.
#   [AnnData(sparse.csr_matrix(a.shape), obs=a.obs) for a in all_adatas],
# /home/gaurav/anaconda3/envs/project/lib/python3.10/site-packages/anndata/_core/anndata.py:1785: FutureWarning: X.dtype being converted to np.float32 from float64. In the next version of anndata (0.9) conversion will not be automatic. Pass dtype explicitly to avoid this warning. Pass `AnnData(X, dtype=X.dtype, ...)` to get the future behavour.
#   [AnnData(sparse.csr_matrix(a.shape), obs=a.obs) for a in all_adatas],
# /home/gaurav/anaconda3/envs/project/lib/python3.10/site-packages/anndata/_core/anndata.py:1785: FutureWarning: X.dtype being converted to np.float32 from float64. In the next version of anndata (0.9) conversion will not be automatic. Pass dtype explicitly to avoid this warning. Pass `AnnData(X, dtype=X.dtype, ...)` to get the future behavour.
#   [AnnData(sparse.csr_matrix(a.shape), obs=a.obs) for a in all_adatas],
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [312], in <cell line: 1>()
# ----> 1 C_mean,C_var,M_mean,M_var = zebra_obj.Simulations(adata_test,5.3,12,"HPF",sim_num=25)
#
# File ~/Gaurav/Berlin/Deep_Learning/Project/deep_predictor.py:431, in DeepPredictor.Simulations(self, adata_t, state_a, state_b, key, sim_num)
#     429 correlation_slope_var = []
#     430 for i in range(sim_num):
# --> 431 	adata_pred,px_scale,theta,px_rate = self.predict(adata_t,state_a,state_b,key)
#     432 	real_data = adata_pred[adata_pred.obs["cells"] == "Real data"]
#     433 	pred_data =  adata_pred[adata_pred.obs["cells"] == "Predicted data"]
#
# File ~/Gaurav/Berlin/Deep_Learning/Project/deep_predictor.py:223, in DeepPredictor.predict(self, adata_t, state_a, state_b, key)
#     220 input_data = torch.empty(np.shape(self.latent_predict)[0], 1)
#     221 library_size = np.mean(np.sum(self.adata_test.X,axis=1))
# --> 223 px_scale,theta,px_rate = self.model.latent_to(self.latent_predict,library=torch.ones_like(input_data))
#     224 recontructed_data = library_size  * px_scale
#     225 adata_predict = sc.AnnData(recontructed_data,obs={"cells": "Predicted data"}, var={"var_names":adata_t.var_names})
#
# File ~/anaconda3/envs/project/lib/python3.10/site-packages/torch/autograd/grad_mode.py:27, in _DecoratorContextManager.__call__.<locals>.decorate_context(*args, **kwargs)
#      24 @functools.wraps(func)
#      25 def decorate_context(*args, **kwargs):
#      26     with self.clone():
# ---> 27         return func(*args, **kwargs)
#
# File ~/Gaurav/Berlin/Deep_Learning/Project/VAEtorch.py:142, in VAEmodel.latent_to(self, z, library)
#     138 @torch.no_grad()
#     139 def latent_to(self, z: Tensor,library) -> np.ndarray:
#     140     #z = torch.from_numpy(input_data)
#     141     #z = torch.tensor(z,dtype=torch.float64)
# --> 142     px_scale,theta,px_rate = self.decoder(z.to(self.device),library)
#     143     return px_scale.detach().numpy(),theta.detach().numpy(),px_rate.detach().numpy()
#
# File ~/Gaurav/Berlin/Deep_Learning/Project/VAEtorch.py:105, in VAEmodel.decoder(self, z, library)
#     103 if (self.likelihood =="nb"):
#     104     px = self.dec(z)
# --> 105     px_scale = self.px_scale_decoder(px)
#     106     px_rate = library * px_scale
#     107     #px_r = torch.exp(self.px_r)
#
# File ~/anaconda3/envs/project/lib/python3.10/site-packages/torch/nn/modules/module.py:1110, in Module._call_impl(self, *input, **kwargs)
#    1106 # If we don't have any hooks, we want to skip the rest of the logic in
#    1107 # this function, and just call forward.
#    1108 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110     return forward_call(*input, **kwargs)
#    1111 # Do not call functions when jit is used
#    1112 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/anaconda3/envs/project/lib/python3.10/site-packages/torch/nn/modules/container.py:141, in Sequential.forward(self, input)
#     139 def forward(self, input):
#     140     for module in self:
# --> 141         input = module(input)
#     142     return input
#
# File ~/anaconda3/envs/project/lib/python3.10/site-packages/torch/nn/modules/module.py:1110, in Module._call_impl(self, *input, **kwargs)
#    1106 # If we don't have any hooks, we want to skip the rest of the logic in
#    1107 # this function, and just call forward.
#    1108 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110     return forward_call(*input, **kwargs)
#    1111 # Do not call functions when jit is used
#    1112 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/anaconda3/envs/project/lib/python3.10/site-packages/torch/nn/modules/activation.py:1261, in Softmax.forward(self, input)
#    1260 def forward(self, input: Tensor) -> Tensor:
# -> 1261     return F.softmax(input, self.dim, _stacklevel=5)
#
# File ~/anaconda3/envs/project/lib/python3.10/site-packages/torch/nn/functional.py:1818, in softmax(input, dim, _stacklevel, dtype)
#    1816     dim = _get_softmax_dim("softmax", input.dim(), _stacklevel)
#    1817 if dtype is None:
# -> 1818     ret = input.softmax(dim)
#    1819 else:
#    1820     ret = input.softmax(dim, dtype=dtype)
#
# KeyboardInterrupt:

# %%
adata_meso_endo_forward.uns["mean_correlations"] = C_mean
adata_meso_endo_forward.uns["std_correlations"] = C_var
adata_meso_endo_forward.uns["mean_slope"] = M_mean
adata_meso_endo_forward.uns["std_slope"] = M_var

# %%
adata_meso_endo_forward.write_h5ad("/home/gaurav/Gaurav/Berlin/Deep_Learning/Project/models/NB_MMD/Objects/Zebrafish/adata_meso_endo_forward_12hpf_.h5ad")
